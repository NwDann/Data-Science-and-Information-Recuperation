# %% [markdown]
# # Ejercicio 1: Introducción a Recuperación de Información
#
# ## Objetivo de la práctica
# - Entender el problema de **buscar información** en colecciones de texto.
# - Comprender por qué se necesita un **índice invertido** en recuperación de información.
# - Programar una primera solución manual y luego optimizarla con un índice.
# - Evaluar la mejora en tiempos de búsqueda cuando usamos estructuras adecuadas.

# %% [markdown]
# ## Parte 1: Búsqueda lineal en documentos
#
# ### Actividad
# 1. Se te proporcionará un dataset con reviews de películas.
# 2. Escribe una función que:
#    - Lea todos los documentos.
#    - Busque una palabra ingresada por el usuario.
#    - Muestre en qué documentos aparece la palabra.

# %%
# Listas, diccionarios y conjuntos en Estructuras de datos
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv')
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
def lineal_search(column, query):
    mask = column.str.contains(query, case=False, na=False)
    return column[mask]

# %%
lineal_search(df["review"], "hello")
# Out:
# 17       This movie made it into one of my top 10 most ...
# 33       One of the most significant quotes from the en...
# 169      The Lives of the Saints starts off with an atm...
# 214      holy Sh*t this was god awful. i sat in the the...
# 649      1983's "Frightmare" is an odd little film. The...
#                                ...
# 48740    Hello again, I have to comment on this wonderf...
# 49310    I claim no matter how hard I seek I'll never f...
# 49856    Man, this gets a lot of good reviews in the re...
# 49960    John Carpenter's career is over if this sad ex...
# 49984    Hello it is I Derrick Cannon and I welcome you...
# Name: review, Length: 185, dtype: object

# %% [markdown]
# ## Parte 2: Construcción de un índice invertido
#
# ### Actividad
# 1. Escribe un programa que:
#    - Recorra todos los documentos.
#    - Construya un **índice invertido**, es decir, un diccionario donde:
#      - Cada palabra clave apunta a una lista de documentos donde aparece.
#
# 2. Escribe una nueva función de búsqueda que:
#    - Consulte directamente el índice para encontrar los documentos relevantes.
#    - Sea mucho más rápida que la búsqueda lineal.

# %% [markdown]
# Este código construye un vocabulario de todas las palabras encontradas con una limpieza muy básica del texto procesado.

# %%
vocab = set(" ".join(df["review"].astype(str)).lower().replace(".", "").replace(",", "").split())
vocab
# Out:
# {'dearest',
#  'amigos',
#  'shown?',
#  'lieutenant-governor',
#  'pankin',
#  "speedman's",
#  'sexed',
#  'creature/sharikov',
#  'swaile',
#  'warde',
#  'mitosis',
#  'nonchalant',
#  'talentlessness',
#  'independent-minded',
#  'deniro-obsessed',
#  'movie"sir"',
#  'vuh',
#  'ncos',
#  '(siyasiyabend',
#  'flat-lined',
#  'ambricourt',
#  '/>merrill',
#  '"blues"',
#  'malcovik',
#  'matey',
#  'semi-clad',
#  'playing!',
#  'hard-hearted',
#  '05/10',
#  'adaptation:',
#  'fashion)<br',
#  'crummyand',
#  'universe<br',
#  'surgically',
#  'arent',
#  '/>greystoke:',
#  'haruhi',
#  '(abe',
#  'sybok?',
#  '"eeeevil"',
#  '/>like',
#  'pirouetted',
#  '3)',
#  "3'",
#  '/>tenacious',
#  'any-',
#  'grips',
#  'cousin)',
#  'vilanch',
#  'suicidedivided',
#  'that<br',
#  'un-human',
#  'intellectual',
#  'wwi<br',
#  '"costumes"',
#  'time)º',
#  'hot<br',
#  'real-man',
#  'energy"',
#  'woman-unfriendly',
#  '/>partial',
#  "90's!<br",
#  'bather',
#  'servant/confidant',
#  "'monsters'",
#  'troupe)',
#  'pseudo-controversial',
#  '/>"une',
#  'johnston-coslow',
#  'przybyszewska',
#  '"solarbabies"',
#  'abishai',
#  'unknown',
#  'dramaand',
#  'necrophilia;',
#  '"victim"',
#  'budget!where',
#  '(thankfully)<br',
#  'disagreements)',
#  'springfield"',
#  'regent<br',
#  'decrying',
#  '(2-2)',
#  'upstage',
#  '"towards-human',
#  'gelin)',
#  "mortimer's",
#  'teethand',
#  '~must~',
#  'paragraph-long',
#  'whatsoeverthere',
#  '(marge',
#  '(keaton)who',
#  '"hunchback"',
#  'jean"',
#  '/>"being',
#  'incomprehesible',
#  'semi-horror',
#  '/>liza',
#  "garrett's",
#  'nails<br',
#  'actor?',
#  '(then)',
#  'bevy',
#  "sharon's",
#  'modestly',
#  '"coven"',
#  '(paxinou)',
#  'methane-pigs',
#  "else'",
#  'seance',
#  'got',
#  'yoshimi',
#  '"stardust"',
#  'brauss',
#  'it!!!!!!this',
#  'yuma!',
#  'sprinted',
#  'slaves;',
#  'hope-inspiringly',
#  'feelcarnewhile',
#  'lended',
#  "cheesy-movie-lover's",
#  'didn´t',
#  '/>cashing',
#  'transplant?',
#  'survivor"',
#  "whereabouts'",
#  'telepathy<br',
#  'ciano',
#  'skatepark',
#  "critique's",
#  '/>atc:',
#  'copyrighted',
#  'youas',
#  '"correct',
#  'b-musicals',
#  'movieplusthere',
#  '(does',
#  'hominids',
#  'jirí',
#  'gays/lesbians',
#  'reveals',
#  '/>bud',
#  'vibes',
#  'bela',
#  'dongle',
#  'hit-or-miss',
#  'skit)',
#  "good'flick!<br",
#  'inaneit',
#  "'angles",
#  'shazam!',
#  '"impulse"',
#  '/>bachelor',
#  'characters(except',
#  'muchyou',
#  '/>wildside',
#  "'fig-leaf'",
#  "warwick's",
#  'meetings?',
#  'gpss',
#  'pdvsa',
#  'hsss',
#  'touch)<br',
#  'rabbey',
#  'speakingthe',
#  'ragnardocks',
#  'rear-view',
#  "losers'",
#  'eduction',
#  'says<br',
#  'rosanna',
#  'sergei(rade',
#  '(gloria)',
#  'judges)',
#  'retarded?',
#  'wallpaper?)',
#  'mating?',
#  'soundtracks;',
#  'filmgreat',
#  'rise?<br',
#  'pyschologist',
#  'button-mashing',
#  '(easy',
#  'ward")',
#  'topless!',
#  'campbell:',
#  'classy-yet-kitsch',
#  'huh-huh',
#  'rating-a',
#  'damned/the',
#  'hated:',
#  'infomercials',
#  'cotten)',
#  '/>cindy',
#  'confused<br',
#  '"abernethie"',
#  'pre-stardom',
#  'sandals"',
#  'gilbert/sullivan',
#  'birgitte',
#  'meyer)',
#  'jr);',
#  'experienceso',
#  'brodský)',
#  'carribbean)',
#  'celebrating',
#  '(tsh-tsh-tsh-ha-ha-ha)',
#  '"gummo"',
#  '(spoiler)---->',
#  '999999%',
#  'sette',
#  'bob',
#  '6:30pm',
#  '"secrets"',
#  'fürmann)',
#  'brandom',
#  'movieespecially',
#  'nyt',
#  'indict',
#  'contemptuous',
#  'weak:',
#  'pools',
#  '(incredibles',
#  'hurry',
#  'doom")<br',
#  'ontkean)',
#  'flaw"',
#  '/>madhur',
#  'discipline<br',
#  'sabretooth"',
#  'too!',
#  'taek',
#  '(melanie',
#  "'cruder'",
#  'october<br',
#  'produer',
#  'it--drivel',
#  'sang',
#  '"rosenstrasse"',
#  'hindrance',
#  'foolbut',
#  'worries!',
#  "'race",
#  'only-',
#  'rebedahl',
#  'gauze-clad',
#  'scene---',
#  'thought-',
#  'explain:<br',
#  "yeahthat's",
#  'greasers',
#  '39th',
#  'category)',
#  "brashear's",
#  'actor(tom',
#  'partsthats',
#  'egyptology',
#  'paradise!!',
#  'sinful',
#  '(moon',
#  'strada',
#  'non-davies',
#  'air<br',
#  '--not',
#  'release!!',
#  'steeplechase',
#  'hans-jurgen',
#  '‘anna',
#  'imdbcom<br',
#  'ebonics-speakers',
#  'pro-chávez',
#  'injustly',
#  'gu',
#  'doldrums',
#  "orlean's",
#  'toomeyand',
#  'interesting"<br',
#  'goofball',
#  'eye-rolling<br',
#  'dark?"',
#  'merits:',
#  'adversion',
#  "/>zane's",
#  'moltisanti',
#  '/>"continue',
#  '"horror"!!',
#  'pew',
#  'pared-down',
#  'arteries',
#  'whoopy',
#  'look!!!!!',
#  'lilain',
#  'tedium',
#  "'she-devil'",
#  'super-hilarious',
#  'harnesses',
#  'pulse(!!)',
#  'boozed-up',
#  '“him”',
#  'feature"--',
#  "wasn't",
#  'unoriginals',
#  'siriaque',
#  'derek’s',
#  'men)?<br',
#  'fridgewhich',
#  'boti',
#  'frontsit',
#  'zuckers',
#  "'true'",
#  'mommy-wife',
#  'funniest',
#  '(fleischer',
#  'score--which',
#  'mahoney-',
#  'humor(who',
#  'flood:',
#  'soorya',
#  'stepfather"',
#  '"question',
#  '/>what’s',
#  '"household-name"',
#  'tomania',
#  'quit"',
#  'co-pilot',
#  'sneedeker',
#  'lily"',
#  'highi',
#  'ratings:<br',
#  'goscinny',
#  'bak',
#  'poetry?)',
#  'mania!',
#  '****/****',
#  'recent',
#  'him;)',
#  'lamebrained',
#  'underlit',
#  'shrieking',
#  'mismatched',
#  'disscusion',
#  '31',
#  'jesus"?',
#  "hunt'",
#  'on-par',
#  'toxicology',
#  'puaro',
#  'filmif',
#  'robintwice',
#  'goooooooooooooooooooood',
#  'mashes',
#  'yolngu',
#  'sociologist',
#  '"disappearing',
#  'aaargh!',
#  'mcmartin',
#  'protest',
#  'nicoli)',
#  'laws"',
#  'cashing',
#  'introspection',
#  'deaf-and-blind',
#  'immediately?',
#  'little)',
#  'appearance!',
#  'cometh',
#  "dwarfs')",
#  'asian-styled',
#  '(chico',
#  'funded?',
#  "whack'",
#  'himselfmaybe',
#  'tract?',
#  'comfortable<br',
#  'dealthe',
#  'saidyou',
#  'faithfully',
#  'smoothly:',
#  '"lefler\'s',
#  'moviedom',
#  'comments)<br',
#  'sayin\'")',
#  'friedhofer',
#  'weekthe',
#  '"discussion',
#  'gand',
#  'woodard(or',
#  "hussein's",
#  '/>mohinish',
#  'salesman!',
#  'relationships(reallyits',
#  '1943',
#  'co-operate)',
#  'skeptic-turned-believer',
#  'europe:',
#  '"production',
#  'impressionism',
#  'thambi',
#  'territories',
#  'wilde',
#  'torture/rape',
#  'skilfully',
#  '-death',
#  '("look',
#  'classic(check',
#  'teamed',
#  'field"',
#  'put:magnificent!',
#  '30mm',
#  '"okul"',
#  'believed!!',
#  '(elsewhere)',
#  '(perfect',
#  'alaimo',
#  'wars(1977)and',
#  'hat"',
#  'ballon',
#  'luke<br',
#  "hoberman's",
#  'not-terrible',
#  'chupacabra!',
#  'inventive-and',
#  'ohana',
#  'ex-wives',
#  'two-second',
#  'buggy',
#  'house")&',
#  "faces'<br",
#  'set-making',
#  'kammer',
#  'italianespecially',
#  'harping',
#  'uproarish',
#  'cartographer',
#  'period)<br',
#  'scoggins',
#  'poorly-conceived',
#  'balances',
#  'friendsgusreminded',
#  'journey)',
#  'strudel?)',
#  'tories',
#  'typo!',
#  'lay',
#  '(lenny)',
#  'courtesan/singer',
#  'coming<br',
#  'linebacker-built',
#  '(nadine',
#  'tholomyes',
#  'attic)',
#  'gammon',
#  '(older?)',
#  'gender-based',
#  'schmoelloer',
#  'tupperware-channel',
#  'ff2',
#  'jail?<br',
#  'poo:',
#  "'underground'or",
#  'desperation!',
#  'faced;',
#  'glovers',
#  'vija',
#  '/>danish-born',
#  'schwarzenegger-wanna',
#  'illusory:',
#  'time-wise;',
#  'performancechunky',
#  '"cracker"',
#  'man(that',
#  'anything?',
#  'flop-sweat',
#  '"withnail',
#  'bowserand',
#  'good-v-evil',
#  'khaki)',
#  'gigi-like',
#  'devolves',
#  'diplomat',
#  'choreography?',
#  'horky',
#  '/>pacino',
#  'prop',
#  'overly-gratuitous',
#  "'wham'--seems",
#  'portrayed',
#  'non-splatter',
#  'art-works',
#  'thugees',
#  '"lower',
#  'baby:',
#  '(prot)',
#  'figure!',
#  '"gripping',
#  'chick(who',
#  'sappers',
#  "'hole'",
#  'dungbut',
#  'jp2',
#  'wildfell',
#  "favelas'",
#  'id"',
#  'mandela)',
#  'wined',
#  'label\x97seville\x97and',
#  '"kali!"',
#  'figaro"<br',
#  "amoretti's",
#  'consistence',
#  'fisherman!!',
#  "stuttgart's",
#  'flower-power',
#  'claudian',
#  'ratingyou',
#  'desdemona',
#  'renant)',
#  "melies'",
#  "ojos'",
#  "balls'",
#  'jlb',
#  "he'd",
#  '/>mix',
#  'yugoslaviamap',
#  'audial',
#  'at)<br',
#  'tinkering',
#  'kip',
#  'boringreallybut',
#  'cuba"',
#  'we"',
#  "nallae'",
#  'revolution?',
#  'media!"<br',
#  'malpractice',
#  "'ratcatcher'",
#  'outdid',
#  'eatingin',
#  "beale's<br",
#  'ability<br',
#  'sins"',
#  '/>reba',
#  '"boring',
#  'sexshop',
#  'scent)<br',
#  'crusoeland"',
#  'toady',
#  'freaks"',
#  'hayes<br',
#  "duguay's",
#  "done's",
#  'meaninglessly)',
#  '/>sensing',
#  'edition;',
#  'malfatti)?',
#  "kuzco's",
#  'traeger)',
#  "bilge's",
#  'virtue-threatened',
#  'knox<br',
#  'monstrous!!',
#  "research'",
#  'balk)',
#  'play/movie',
#  "crew'",
#  "henri's",
#  'robicheaux',
#  "fanboy's",
#  'flat-screen',
#  'post-carbon',
#  'hot-shot',
#  '“the',
#  'emperor)',
#  'daily--in',
#  'beachthis',
#  'here!)but',
#  'oop',
#  'clanky',
#  'work--or',
#  'alternations',
#  '"expect"',
#  'fixit"',
#  'masanori',
#  "'peaches'",
#  'suppose!!!<br',
#  'popstar;',
#  '(pinky)',
#  "'hired",
#  'backlike',
#  '/>harrowing',
#  'studder',
#  'sizesthis',
#  "malloy's",
#  'flying',
#  'sylvialeonand',
#  'neglected',
#  'branching',
#  '/>hahaha',
#  'riah',
#  'predator)',
#  'oberoi',
#  'crappest',
#  'excrement?',
#  'chapple',
#  'mistake?',
#  'skammen)',
#  'director)',
#  'nerd',
#  '/>doug',
#  'ideals/cultures;',
#  'magnolias"',
#  'violating',
#  'hourly',
#  'sexist-but-loving-husband',
#  'gyspy',
#  'filmtom',
#  'ryhs-davies',
#  "fillmore's",
#  'videozone',
#  'heartfelt<br',
#  'rating"',
#  'kitni',
#  'prefigured',
#  'cathedral-sized',
#  'housemaid',
#  'kika',
#  'software-approved',
#  '"battlefield"',
#  'light-speed',
#  "'underworld'",
#  '100-year-old',
#  "seek'",
#  'undone?',
#  'hero/male',
#  'streets<br',
#  "charlie's",
#  'vowel',
#  'half-threat',
#  'cargo)',
#  'pro-wrestling',
#  "amen'",
#  'investors',
#  'vidmer',
#  'all-for-me',
#  'heart-shaped',
#  "-you'll",
#  'appropriate:',
#  'tenuta',
#  "laughter'",
#  "50's-style",
#  'jitsu',
#  'radars',
#  'insanities',
#  'investigationtours',
#  'target;',
#  'mannequin/wax',
#  'recording<br',
#  'handguns',
#  'summers(candice',
#  'bodied',
#  'concorde/new',
#  'sceneits',
#  'gnosticism',
#  'homesetting',
#  '(56)',
#  'smoking!',
#  '#stein',
#  'suffuses',
#  'speakeasy',
#  'z-plan',
#  'cambodia)a',
#  'brother-in-law)',
#  '/>personally',
#  'head!)',
#  'unfortuntately',
#  'correctmaybe',
#  'languid',
#  '"haiku',
#  'chiller<br',
#  'approximate):',
#  'whisperings',
#  'sanders"',
#  'role(though',
#  "'skins'",
#  'wags<br',
#  'cop)',
#  'favorite)armand',
#  'underwriters',
#  'hardly!!!',
#  "it'd",
#  'blitzkrieg',
#  'kicks!)',
#  'eaker',
#  'timeclock',
#  'alesia',
#  'plagiarized',
#  'yell<br',
#  'breasts?',
#  'fling',
#  'maxime',
#  'languorously',
#  '28',
#  'cormanized',
#  'ps3',
#  'millardo',
#  'televised-before-death',
#  'fight!!!"<br',
#  'murray"',
#  'pretty-much',
#  'buttons)',
#  '/>ponyo',
#  'ploy<br',
#  'laboratory',
#  'multi-weapon',
#  '/>70s',
#  'avoidable<br',
#  'unattractivein',
#  '(valenti',
#  'snuka<br',
#  '(imbd',
#  'stereo<br',
#  'fluster',
#  'suspects"',
#  'mauricio',
#  'diminishing-return',
#  'backsides',
#  'chattering',
#  'sooneach',
#  'stitches!',
#  '(sig)',
#  'hisermtrue',
#  "achilleas's",
#  '--',
#  'grievously',
#  "'faux",
#  'pre-destined',
#  'olmstead)',
#  'gawd!"',
#  'attitude)<br',
#  'tornadoes)',
#  'peeking',
#  'testosterone-overloaded',
#  'storyeven',
#  'custodial',
#  'ante',
#  'epsilon',
#  'sanam"',
#  'giddeon',
#  "act'",
#  'dispised',
#  'superhero/fantasy/sci-fi',
#  'harlem"',
#  'thompsonwhat',
#  'demonstration;',
#  'lantos(producer9and',
#  'stonehenge',
#  'advertised);',
#  'mcgreevey',
#  'auie',
#  'non-cliche',
#  'ladies!!',
#  'famishius"',
#  'stoners',
#  'files*',
#  "blooded'",
#  "forgot'",
#  'illustrative',
#  'fansespecially',
#  'metallo',
#  "'larry",
#  'touching:',
#  'over-arch<br',
#  'milkshake',
#  'mummy-',
#  '100k',
#  'chomet?',
#  'real])<br',
#  'else<br',
#  '(brian)',
#  'passers-by<br',
#  "11'",
#  'sweep?',
#  'schoolroom)',
#  '"tito',
#  '/>water',
#  'interference',
#  'rsl',
#  'locksmith',
#  "dominance'",
#  'olympiad',
#  'warlock<br',
#  'realistically(i',
#  '/>him',
#  'interplay',
#  'kickings',
#  'self-evolving',
#  'federline"',
#  '"microcosm"',
#  'controlsand',
#  'staffs',
#  'ppv',
#  'brain-slurping',
#  'awlright',
#  'bluster',
#  'father?<br',
#  'insights--which',
#  'an-old-song-to-evoke-the-period',
#  'cans',
#  '"inspire"',
#  'issacs',
#  'spoilerish<br',
#  'abilities-',
#  'actor<br',
#  'hal9000',
#  'coaster',
#  'citta',
#  'on?',
#  'gnostic',
#  'bonnaducci',
#  'rings(',
#  'nascent',
#  '"special"?)',
#  'tracie',
#  "rn's",
#  'paradoxically',
#  'allosaurus',
#  'psi',
#  'many);',
#  'masters(kyd',
#  'goeswell',
#  'plot-tool',
#  '"noir"',
#  '"hercules:',
#  '"robert',
#  'witching',
#  "'mutant",
#  'blend',
#  'penny!',
#  'carefully--there',
#  'bullet!',
#  'patriotic',
#  'mass-murder',
#  'dialogues?',
#  'hootkloot',
#  '/>hitchcock',
#  '"anna',
#  'picture!<br',
#  "farina's",
#  'huppertz',
#  'koshiro',
#  'industrythough',
#  'dixxon',
#  'ike',
#  'mesmorizing',
#  'points"',
#  'southstreet',
#  '"titan',
#  'krel',
#  'czars',
#  'film---but',
#  'venturesome',
#  'debonair"',
#  'screenplay;',
#  'toy-car',
#  "gustav's",
#  'category;',
#  '"equinox',
#  'jeeez!',
#  '"alexander"',
#  'under-parr',
#  'schoolboy;',
#  'tesmacher',
#  'proof"',
#  'story:',
#  'threesome):',
#  'bovine-like',
#  'german!?!!',
#  "'stunt",
#  '/>-one',
#  'eggs:',
#  "stalin's",
#  'good:stephen',
#  'colour',
#  'peking"',
#  '"great"',
#  "sandgren's",
#  'illogical:',
#  'actingthe',
#  'creepy-looking',
#  'wogs(the',
#  'agreeably',
#  "'treated'",
#  'knitt',
#  'sam',
#  'spoilers)well',
#  'witting',
#  'vote:',
#  '"darkman',
#  'fye-tal',
#  '"costa',
#  'pom',
#  'dark(eventually',
#  '"loser")',
#  'marriage)',
#  'emoting)',
#  'profile',
#  'dummy-as-dead-body',
#  'mortician',
#  'childbearing',
#  'benjy',
#  'adaptors',
#  'forgetfulness)',
#  'hereit',
#  'loder',
#  'artificially-enhanced',
#  'pretzels',
#  'putrescent',
#  'kerova',
#  're-constructed',
#  'yas',
#  'unexpected',
#  'nearly-abandoned',
#  'erotic',
#  'producers',
#  'law"!)',
#  'einon',
#  '"wilder',
#  'open"!!!!!',
#  '"wogs"',
#  'journey\x97such',
#  'debating-clubs',
#  "singleton's",
#  'ghoulie-puppets',
#  'bendingly',
#  'housecleaning',
#  'allégret',
#  'horror/sex',
#  '_think_',
#  'cyberworld',
#  'sea?<br',
#  'weekends',
#  'composed',
#  'parents/brothers',
#  '(heurtebise)',
#  'promised)',
#  '(b&w',
#  'hungarian!<br',
#  'terrifies',
#  '"needs"',
#  'store!)',
#  'kartalian',
#  'woodworks',
#  'nets"',
#  'epic/tragic',
#  '/>peter',
#  "dalton's",
#  'black-spray-painted',
#  '$700',
#  'grey?',
#  'yelena',
#  '"werewolf";',
#  'newsreader',
#  'wardrobe!?',
#  'associating',
#  'pageant<br',
#  '(woman',
#  '--if',
#  'peck-it',
#  'barnstorming',
#  'possible!)',
#  'executed;',
#  'ormand',
#  'character-defining',
#  'pig)he',
#  'mcbeal?',
#  'pointless)1992',
#  'house-wife',
#  'include:',
#  'airscrew)',
#  'vanilla"',
#  "connecticut'",
#  'lewton',
#  'long-running',
#  "war's",
#  'moviebut',
#  'cinesound',
#  'hospital");',
#  'umbrella',
#  'truthfulness',
#  '(o-shin',
#  "nose--i'd",
#  'atrocitybut',
#  '8/10which',
#  'cognac',
#  'affairs<br',
#  'arguing:',
#  'busi',
#  '(bella',
#  ...}

# %%
len(vocab)
# Out:
# 297583

# %% [markdown]
# En esta parte construimos el diccionario que nos servirá de índice para ayudarnos en la búsqueda después.

# %%
results = dict()
for word in vocab:
    try:
        results[word] = lineal_search(df["review"], word).index
    except Exception as e:
        print(word)

results
# Out:
# (siyasiyabend
# fashion)<br
# (abe
# 3)
# cousin)
# time)º
# troupe)
# /tmp/ipykernel_37/236026943.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = column.str.contains(query, case=False, na=False)
# disagreements)
# gelin)
# (marge
# (does
# skit)
# characters(except
# touch)<br
# sergei(rade
# judges)
# wallpaper?)
# (easy
# ward")
# cotten)
# meyer)
# jr);
# brodský)
# carribbean)
# fürmann)
# (incredibles
# doom")<br
# ontkean)
# (melanie
# category)
# actor(tom
# (moon
# men)?<br
# (fleischer
# humor(who
# poetry?)
# ****/****
# him;)
# nicoli)
# little)
# dwarfs')
# (chico
# comments)<br
# sayin'")
# woodard(or
# relationships(reallyits
# co-operate)
# ("look
# classic(check
# (perfect
# house")&
# period)<br
# journey)
# strudel?)
# (nadine
# attic)
# man(that
# khaki)
# chick(who
# mandela)
# renant)
# at)<br
# scent)<br
# meaninglessly)
# malfatti)?
# traeger)
# balk)
# emperor)
# here!)but
# predator)
# skammen)
# director)
# cargo)
# summers(candice
# cambodia)a
# brother-in-law)
# head!)
# approximate):
# role(though
# cop)
# favorite)armand
# kicks!)
# buttons)
# (valenti
# (imbd
# olmstead)
# attitude)<br
# tornadoes)
# lantos(producer9and
# advertised);
# real])<br
# schoolroom)
# realistically(i
# rings(
# "special"?)
# many);
# masters(kyd
# threesome):
# wogs(the
# spoilers)well
# dark(eventually
# "loser")
# marriage)
# emoting)
# forgetfulness)
# law"!)
# promised)
# (b&w
# store!)
# (woman
# possible!)
# pig)he
# pointless)1992
# airscrew)
# hospital");
# (o-shin
# (bella
# knightley)
# jones)
# course!)steven
# suggests)
# wrath')
# wrong)
# oxide)
# (featured
# friends!)<br
# maldera)
# context)
# terrible!)
# dallas)
# serrafin)
# (besides
# streep!)
# (plentiful!
# (camerawork
# want?)
# canada!)<br
# margot)<br
# destructive)
# you!)
# land)"
# (oyama
# translators)
# (shia
# breathtaking)
# iures)
# inconsistency);
# torres)
# "character?")
# burden)
# papas)
# nicoli)and
# confirm)
# (deformed
# boots)
# math)<br
# verma)
# pentagon)think
# (particually
# *book*
# *reasons*
# hwaa!!")<br
# (burt
# buster)
# (francoise
# eragon)
# aspect)
# (cuba
# richards)
# (det
# long)
# 1955-60)<br
# goonies)
# role(i
# laughs!")
# ups)
# again)
# actors(but
# liking)
# 45)
# (dee
# vardon)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_37/910703010.py in <cell line: 0>()
#       2 for word in vocab:
#       3     try:
# ----> 4         results[word] = lineal_search(df["review"], word).index
#       5     except Exception as e:
#       6         print(word)
#
# /tmp/ipykernel_37/236026943.py in lineal_search(column, query)
#       1 def lineal_search(column, query):
# ----> 2     mask = column.str.contains(query, case=False, na=False)
#       3     return column[mask]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     135                 )
#     136                 raise TypeError(msg)
# --> 137             return func(self, *args, **kwargs)
#     138
#     139         wrapper.__name__ = func_name
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/accessor.py in contains(self, pat, case, flags, na, regex)
#    1333             )
#    1334
# -> 1335         result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1336         return self._wrap_result(result, fill_value=na, returns_string=False)
#    1337
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/object_array.py in _str_contains(self, pat, case, flags, na, regex)
#     143                 upper_pat = pat.upper()
#     144                 f = lambda x: upper_pat in x.upper()
# --> 145         return self._str_map(f, na, dtype=np.dtype("bool"))
#     146
#     147     def _str_startswith(self, pat, na=None):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/object_array.py in _str_map(self, f, na_value, dtype, convert)
#      76         map_convert = convert and not np.all(mask)
#      77         try:
# ---> 78             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      79         except (TypeError, AttributeError) as err:
#      80             # Reraise the exception if callable `f` got wrong number of args.
#
# lib.pyx in pandas._libs.lib.map_infer_mask()
#
# lib.pyx in pandas._libs.lib._map_infer_mask()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/object_array.py in <lambda>(x)
#     136             pat = re.compile(pat, flags=flags)
#     137
# --> 138             f = lambda x: pat.search(x) is not None
#     139         else:
#     140             if case:
#
# KeyboardInterrupt:

# %% [markdown]
# Después, definimos una función que se encarga de consultar el anterior diccionario para traernos los documentos que contengan la palabra.

# %%
def inverted_index_search(dataframe, dictionary, query):
    return dataframe.loc[dictionary[query]]

# %% [markdown]
# Este es un ejemplo de una consulta indexada

# %%
# Quiero buscar la palabra wait

inverted_index_search(df, results, "wait")

# %% [markdown]
# ## Parte 3: Evaluación de tiempos de búsqueda
# ### Actividad
#
# 1. Realiza la búsqueda de varias palabras usando:
#       -  Corpus pequeño.
#       -  Corpus grande.
# 2. Mide el tiempo de ejecución:
#       -  Para búsqueda lineal.
#       -  Para búsqueda usando índice invertido.
#       -  Grafica o presenta los resultados en una tabla comparativa.

# %%
# df_large = pd.read_csv('rotten_tomatoes_movie_reviews.csv.zip', compression='zip')
df_large = pd.read_csv("/kaggle/input/rotten-tomatoes-movies-and-critic-reviews-dataset/rotten_tomatoes_critic_reviews.csv")
df_large

# %%
vocab = set(" ".join(df_large["review_content"].astype(str)).lower().replace(".", "").replace(",", "").split())

results = dict()
for word in vocab:
    try:
        results[word] = lineal_search(df["review"], word).index
    except Exception as e:
        print(word)

results

# %%
# Ahora buscare la palabra tomatoes
inverted_index_search(df_large, results, "tomatoes")

# %% [markdown]
# # Medir tiempos
#
# Búsqueda lineal:

# %%
import time

# %%
inicio = time.time()

lineal_search(df_large["review_content"], "tomatoes")

final = time.time()

tiempo_ejecucion_ms = (final - inicio) * 1000
print(f"Tiempo de ejecución: {tiempo_ejecucion_ms:.2f} milisegundos")

# %% [markdown]
# Búsqueda por índices invertidos

# %%
inicio = time.time()

inverted_index_search(df_large, results, "tomatoes")

final = time.time()

tiempo_ejecucion_ms = (final - inicio) * 1000
print(f"Tiempo de ejecución: {tiempo_ejecucion_ms:.2f} milisegundos")
